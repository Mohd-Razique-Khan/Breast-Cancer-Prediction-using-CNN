# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv1D, MaxPool1D,Flatten,Dense,Dropout,BatchNormalization
from tensorflow.keras.optimizers import Adam

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn import datasets,metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
cancerData = datasets.load_breast_cancer()

# %%
X = pd.DataFrame(data = cancerData.data, columns=cancerData.feature_names )
X.head()
X.shape
X
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# 0                   0.07871  ...        25.380          17.33
# 1                   0.05667  ...        24.990          23.41
# 2                   0.05999  ...        23.570          25.53
# 3                   0.09744  ...        14.910          26.50
# 4                   0.05883  ...        22.540          16.67
# ..                      ...  ...           ...            ...
# 564                 0.05623  ...        25.450          26.40
# 565                 0.05533  ...        23.690          38.25
# 566                 0.05648  ...        18.980          34.12
# 567                 0.07016  ...        25.740          39.42
# 568                 0.05884  ...         9.456          30.37
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# 0             184.60      2019.0           0.16220            0.66560
# 1             158.80      1956.0           0.12380            0.18660
# 2             152.50      1709.0           0.14440            0.42450
# 3              98.87       567.7           0.20980            0.86630
# 4             152.20      1575.0           0.13740            0.20500
# ..               ...         ...               ...                ...
# 564           166.10      2027.0           0.14100            0.21130
# 565           155.00      1731.0           0.11660            0.19220
# 566           126.70      1124.0           0.11390            0.30940
# 567           184.60      1821.0           0.16500            0.86810
# 568            59.16       268.6           0.08996            0.06444
#
#      worst concavity  worst concave points  worst symmetry  \
# 0             0.7119                0.2654          0.4601
# 1             0.2416                0.1860          0.2750
# 2             0.4504                0.2430          0.3613
# 3             0.6869                0.2575          0.6638
# 4             0.4000                0.1625          0.2364
# ..               ...                   ...             ...
# 564           0.4107                0.2216          0.2060
# 565           0.3215                0.1628          0.2572
# 566           0.3403                0.1418          0.2218
# 567           0.9387                0.2650          0.4087
# 568           0.0000                0.0000          0.2871
#
#      worst fractal dimension
# 0                    0.11890
# 1                    0.08902
# 2                    0.08758
# 3                    0.17300
# 4                    0.07678
# ..                       ...
# 564                  0.07115
# 565                  0.06637
# 566                  0.07820
# 567                  0.12400
# 568                  0.07039
#
# [569 rows x 30 columns]

# %%
y = cancerData.target

# %%
X.shape
# Out:
# (569, 30)

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.1,stratify=y)

# %%
X_train.shape
# Out:
# (512, 30)

# %%
y_test.shape
# Out:
# (57,)

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train = X_train.reshape(512,30,1)
X_test = X_test.reshape(57,30,1)

# %%
model = Sequential()
model.add(Conv1D(filters=16,kernel_size=2,activation='relu',input_shape=(30,1)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Conv1D(32,2,activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(32,activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_6 (Conv1D)           (None, 29, 16)            48
#
#  batch_normalization_6 (Bat  (None, 29, 16)            64
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 29, 16)            0
#
#  conv1d_7 (Conv1D)           (None, 28, 32)            1056
#
#  batch_normalization_7 (Bat  (None, 28, 32)            128
#  chNormalization)
#
#  dropout_10 (Dropout)        (None, 28, 32)            0
#
#  flatten_3 (Flatten)         (None, 896)               0
#
#  dense_6 (Dense)             (None, 32)                28704
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 30033 (117.32 KB)
# Trainable params: 29937 (116.94 KB)
# Non-trainable params: 96 (384.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate=0.0001),loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X_train,y_train,epochs=35,verbose=1,validation_data=(X_test,y_test))
# Out:
# Epoch 1/35
# 16/16 [==============================] - 2s 24ms/step - loss: 0.7771 - accuracy: 0.5762 - val_loss: 0.6002 - val_accuracy: 0.8772
# Epoch 2/35
# 16/16 [==============================] - 0s 12ms/step - loss: 0.4854 - accuracy: 0.7559 - val_loss: 0.5488 - val_accuracy: 0.9123
# Epoch 3/35
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3792 - accuracy: 0.8164 - val_loss: 0.5013 - val_accuracy: 0.9298
# Epoch 4/35
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3304 - accuracy: 0.8633 - val_loss: 0.4587 - val_accuracy: 0.9649
# Epoch 5/35
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2741 - accuracy: 0.8867 - val_loss: 0.4220 - val_accuracy: 0.9474
# Epoch 6/35
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2293 - accuracy: 0.9102 - val_loss: 0.3856 - val_accuracy: 0.9123
# Epoch 7/35
# 16/16 [==============================] - 0s 8ms/step - loss: 0.2217 - accuracy: 0.8926 - val_loss: 0.3553 - val_accuracy: 0.9123
# Epoch 8/35
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1927 - accuracy: 0.9277 - val_loss: 0.3260 - val_accuracy: 0.9123
# Epoch 9/35
# 16/16 [==============================] - 0s 8ms/step - loss: 0.1667 - accuracy: 0.9492 - val_loss: 0.3021 - val_accuracy: 0.9123
# Epoch 10/35
# 16/16 [==============================] - 0s 8ms/step - loss: 0.1771 - accuracy: 0.9277 - val_loss: 0.2828 - val_accuracy: 0.8947
# Epoch 11/35
# 16/16 [==============================] - 0s 8ms/step - loss: 0.1371 - accuracy: 0.9512 - val_loss: 0.2632 - val_accuracy: 0.8947
# Epoch 12/35
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1433 - accuracy: 0.9395 - val_loss: 0.2456 - val_accuracy: 0.9123
# Epoch 13/35
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1346 - accuracy: 0.9531 - val_loss: 0.2319 - val_accuracy: 0.9298
# Epoch 14/35
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1237 - accuracy: 0.9512 - val_loss: 0.2186 - val_accuracy: 0.9474
# Epoch 15/35
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1271 - accuracy: 0.9512 - val_loss: 0.2032 - val_accuracy: 0.9474
# Epoch 16/35
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1315 - accuracy: 0.9551 - val_loss: 0.1896 - val_accuracy: 0.9474
# Epoch 17/35
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1136 - accuracy: 0.9590 - val_loss: 0.1789 - val_accuracy: 0.9649
# Epoch 18/35
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1198 - accuracy: 0.9570 - val_loss: 0.1707 - val_accuracy: 0.9649
# Epoch 19/35
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1163 - accuracy: 0.9590 - val_loss: 0.1641 - val_accuracy: 0.9649
# Epoch 20/35
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1153 - accuracy: 0.9609 - val_loss: 0.1610 - val_accuracy: 0.9649
# Epoch 21/35
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1130 - accuracy: 0.9590 - val_loss: 0.1561 - val_accuracy: 0.9649
# Epoch 22/35
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0951 - accuracy: 0.9648 - val_loss: 0.1512 - val_accuracy: 0.9649
# Epoch 23/35
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0924 - accuracy: 0.9688 - val_loss: 0.1484 - val_accuracy: 0.9649
# Epoch 24/35
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0963 - accuracy: 0.9648 - val_loss: 0.1444 - val_accuracy: 0.9649
# Epoch 25/35
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0843 - accuracy: 0.9727 - val_loss: 0.1416 - val_accuracy: 0.9649
# Epoch 26/35
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0700 - accuracy: 0.9766 - val_loss: 0.1383 - val_accuracy: 0.9649
# Epoch 27/35
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0829 - accuracy: 0.9707 - val_loss: 0.1359 - val_accuracy: 0.9649
# Epoch 28/35
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0885 - accuracy: 0.9688 - val_loss: 0.1340 - val_accuracy: 0.9649
# Epoch 29/35
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0857 - accuracy: 0.9648 - val_loss: 0.1327 - val_accuracy: 0.9649
# Epoch 30/35
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0713 - accuracy: 0.9766 - val_loss: 0.1328 - val_accuracy: 0.9649
# Epoch 31/35
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0880 - accuracy: 0.9609 - val_loss: 0.1331 - val_accuracy: 0.9649
# Epoch 32/35
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0767 - accuracy: 0.9746 - val_loss: 0.1319 - val_accuracy: 0.9649
# Epoch 33/35
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0756 - accuracy: 0.9785 - val_loss: 0.1313 - val_accuracy: 0.9649
# Epoch 34/35
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0621 - accuracy: 0.9805 - val_loss: 0.1305 - val_accuracy: 0.9649
# Epoch 35/35
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0645 - accuracy: 0.9785 - val_loss: 0.1305 - val_accuracy: 0.9649

# %%
def plotLearningCurve(history,epochs):
  epochRange = range(1,epochs+1)
  plt.plot(epochRange,history.history['accuracy'])
  plt.plot(epochRange,history.history['val_accuracy'])
  plt.title('Model Accuracy')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.legend(['Train','Validation'],loc='upper left')
  plt.show()

  plt.plot(epochRange,history.history['loss'])
  plt.plot(epochRange,history.history['val_loss'])
  plt.title('Model Loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend(['Train','Validation'],loc='upper left')
  plt.show()

# %%
plotLearningCurve(history,35)
